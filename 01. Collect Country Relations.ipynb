# %%
import pandas as pd
import nltk
from entity_extraction import get_cameo_mappings, parse_sentence, tokenize, format_parsed_str, send_to_petr
import csv
import json
from tqdm import tqdm
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lawli\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\lawli\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
news = pd.read_json("News_Category_Dataset_v3.json", lines= "True")
news = news[news['category'] != "SPORTS"]
news.reset_index(inplace=True)
print(news.shape)
news.head()
# Out:
# (204450, 7)
#    index                                               link  \
# 0      0  https://www.huffpost.com/entry/covid-boosters-...
# 1      1  https://www.huffpost.com/entry/american-airlin...
# 2      2  https://www.huffpost.com/entry/funniest-tweets...
# 3      3  https://www.huffpost.com/entry/funniest-parent...
# 4      4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# 2  "Until you have a dog you don't understand wha...         Elyse Wanshel
# 3  "Accidentally put grown-up toothpaste on my to...      Caroline Bologna
# 4  Amy Cooper accused investment firm Franklin Te...        Nina Golgowski
#
#         date
# 0 2022-09-23
# 1 2022-09-23
# 2 2022-09-23
# 3 2022-09-23
# 4 2022-09-22

# %%
config_path = "config.ini"
map_dict = get_cameo_mappings(config_path)

# %%
def get_entity_information(df):
    story_id = str(df[0])
    text = df[2] + ". " +  df[4]
    date = "202209230908"

    event_dict = {story_id: {}}
    event_dict[story_id]["sents"] = {}
    event_dict[story_id]["meta"] = {}
    event_dict[story_id]["meta"]["date"] = date

    sentences = nltk.sent_tokenize(text)

    for i, _ in enumerate(sentences):
        sent = sentences[i]
        event_dict[story_id]["sents"][str(i)] = {}
        event_dict[story_id]["sents"][str(i)]["content"] = ' '.join(tokenize(sent))
        corenlp_parsed = parse_sentence(sent)
        event_dict[story_id]["sents"][str(i)]["parsed"] = format_parsed_str(corenlp_parsed)
    event_updated = send_to_petr(event_dict)
    event_updated[story_id]["meta"]["date"] = df[6]
    return event_updated

def resolve_list(x):
    if isinstance(x, list):
        return [a for i in x for a in resolve_list(i)]
    else:
        return [str(x).strip().lower()]

def resolve_list_join(x):

    if isinstance(x, list):
        if any(isinstance(item, list) for item in x):
            return [a for i in x for a in resolve_list(i)]
        else:
            return [" ".join(x).strip().lower()]
    else:
        return [x.strip().lower()]

# %%
field_names = ['link', 'headline', 'category', 'short_description', 'authors', 'date',
              'actor1', 'actor2', 'event_code', 'goldstein_score', 'nouns', 'actortext', 'actorroot',
              'eventtext', 'issues', 'events']

country_relations = pd.DataFrame(columns = field_names)
country_relations.head()
# Out:
# Empty DataFrame
# Columns: [link, headline, category, short_description, authors, date, actor1, actor2, event_code, goldstein_score, nouns, actortext, actorroot, eventtext, issues, events]
# Index: []

# %%
rows = []
start = 0
interval = 100
end = start + interval
i = start

drop_rows = [28473, 65613, 73486, 119174, 124136, 125657, 128507, 128562, 177432, 182749, 206601]
news_resume = news.iloc[start : ][:]
drop_index = news_resume[news_resume['index'].isin(drop_rows)].index
news_resume.drop(drop_index, inplace=True)
news_resume.head(45)

total = news.shape[0]

for row in tqdm(news_resume.iterrows()):

    if i >= start and i <end:
        
        info = get_entity_information(row[1]) 
        story_id = str(list(info.keys())[0])

        if info[story_id]['sents']:
            for sent in info[story_id]['sents']:

                if 'events' in info[story_id]['sents'][sent]:

                    row_dict = { column_name : None for column_name in field_names }

                    row_dict['events'] = resolve_list(info[story_id]['sents'][sent]['events'])
                    row_dict['link'] = row[1][1]
                    row_dict['headline'] = row[1][2]
                    row_dict['short_description'] = row[1][4]
                    row_dict['authors'] = row[1][5]
                    row_dict['date'] = str(row[1][6])
                    row_dict['category'] = row[1][3]
                    row_dict['actor1'] = row_dict['events'][0]
                    row_dict['actor2'] = row_dict['events'][1]
                    row_dict['event_code'] = row_dict['events'][2]
                    try:
                        row_dict['goldstein_score'] = map_dict[row_dict['event_code']]
                    except:
                        print("skipping..")
                    row_dict['nouns'] = resolve_list_join(info[story_id]['sents'][sent]['meta']['nouns'])
                    row_dict['actortext'] = resolve_list(info[story_id]['sents'][sent]['meta']['actortext'])
                    row_dict['actorroot'] = resolve_list(info[story_id]['sents'][sent]['meta']['actorroot'])
                    row_dict['eventtext'] = resolve_list(info[story_id]['sents'][sent]['meta']['eventtext'])

                    if 'issues' in info[story_id]['sents'][sent]:
                        row_dict['issues'] = resolve_list(info[story_id]['sents'][sent]['issues'])
                    
                    rows.append(row_dict)
 
    else:
        print(f"Processing rows {start} to {end} out of {total} total rows")
        print(f"Saving {start} to {end} to disk...")
        country_relations_dict = pd.DataFrame.from_dict(rows)
        country_relations_dict.to_json(f"json_dir/country_relations_{start}_{end}.json", indent = 2)
        rows = []
        
        start = end
        end = end + interval
        
    i += 1
    
    if i > total:
        break
# Out:
# 100it [02:05,  1.05it/s]
# Processing rows 203200 to 203300 out of 204450 total rows
# Saving 203200 to 203300 to disk...
# 200it [03:39,  1.24it/s]
# Processing rows 203300 to 203400 out of 204450 total rows
# Saving 203300 to 203400 to disk...
# 300it [05:10,  1.64it/s]
# Processing rows 203400 to 203500 out of 204450 total rows
# Saving 203400 to 203500 to disk...
# 400it [06:50,  1.16it/s]
# Processing rows 203500 to 203600 out of 204450 total rows
# Saving 203500 to 203600 to disk...
# 500it [08:44,  2.15s/it]
# Processing rows 203600 to 203700 out of 204450 total rows
# Saving 203600 to 203700 to disk...
# 600it [10:27,  1.74s/it]
# Processing rows 203700 to 203800 out of 204450 total rows
# Saving 203700 to 203800 to disk...
# 700it [12:13,  1.85it/s]
# Processing rows 203800 to 203900 out of 204450 total rows
# Saving 203800 to 203900 to disk...
# 800it [13:51,  1.40it/s]
# Processing rows 203900 to 204000 out of 204450 total rows
# Saving 203900 to 204000 to disk...
# 900it [15:42,  1.10it/s]
# Processing rows 204000 to 204100 out of 204450 total rows
# Saving 204000 to 204100 to disk...
# 1000it [17:30,  1.65it/s]
# Processing rows 204100 to 204200 out of 204450 total rows
# Saving 204100 to 204200 to disk...
# 1100it [19:16,  1.27s/it]
# Processing rows 204200 to 204300 out of 204450 total rows
# Saving 204200 to 204300 to disk...
# 1200it [20:59,  1.21it/s]
# Processing rows 204300 to 204400 out of 204450 total rows
# Saving 204300 to 204400 to disk...
# 1250it [21:51,  1.05s/it]

# %%
import glob, os

json_dir = 'json_dir'

json_pattern = os.path.join(json_dir, '*.json')
file_list = glob.glob(json_pattern)

country_relations = pd.DataFrame(columns = field_names)

for file in file_list:
    temp_df = pd.read_json(file)
    country_relations = pd.concat([country_relations, temp_df], axis =0)

country_relations.reset_index(inplace=True)
country_relations.drop(['index'], axis = 1, inplace =True)
print(country_relations.shape)
country_relations.head(40)
# Out:
# (5075, 16)
#                                                  link  \
# 0   https://www.huffpost.com/entry/reporter-gets-a...
# 1   https://www.huffpost.com/entry/puerto-rico-wat...
# 2   https://www.huffpost.com/entry/russian-control...
# 3   https://www.huffpost.com/entry/mark-frerichs-r...
# 4   https://www.huffpost.com/entry/bc-as-pakistan-...
# 5   https://www.huffpost.com/entry/african-land-sn...
# 6   https://www.huffpost.com/entry/afghan-adjustme...
# 7   https://www.huffpost.com/entry/sept-11-anniver...
# 8   https://www.huffpost.com/entry/ukraine-forces-...
# 9   https://www.huffpost.com/entry/newspaper-front...
# 10  https://www.huffpost.com/entry/clark-county-of...
# 11  https://www.huffpost.com/entry/meta-400-millio...
# 12  https://www.huffpost.com/entry/bc-us-texas-sch...
# 13  https://www.huffingtonpost.com/entry/obamas-fo...
# 14  https://www.huffingtonpost.com/entry/goodbye-t...
# 15  https://www.huffingtonpost.com/entry/virgin-pr...
# 16  https://www.huffingtonpost.com/entry/can-stude...
# 17  https://www.huffingtonpost.com/entry/south-kor...
# 18  https://www.huffingtonpost.com/entry/trump-mic...
# 19  https://www.huffingtonpost.com/entry/scott-pru...
# 20  https://www.huffingtonpost.com/entry/ronny-jac...
# 21  https://www.huffpost.com/entry/senate-passes-h...
# 22  https://www.huffpost.com/entry/senate-passes-h...
# 23  https://www.huffpost.com/entry/nyc-sheds-vacci...
# 24  https://www.huffpost.com/entry/moldova-us-supp...
# 25  https://www.huffpost.com/entry/utah-transgende...
# 26  https://www.huffpost.com/entry/vice-president-...
# 27  https://www.huffpost.com/entry/children-dead-u...
# 28  https://www.huffpost.com/entry/children-dead-u...
# 29  https://www.huffpost.com/entry/car-into-presch...
# 30  https://www.huffpost.com/entry/new-jersey-draf...
# 31  https://www.huffpost.com/entry/us-supreme-cour...
# 32  https://www.huffpost.com/entry/purdue-pharma-u...
# 33  https://www.huffpost.com/entry/bc-us-state-of-...
# 34  https://www.huffpost.com/entry/united-nations-...
# 35  https://www.huffpost.com/entry/russia-ukraine-...
# 36  https://www.huffpost.com/entry/european-union-...
# 37  https://www.huffpost.com/entry/ukraine-russia-...
# 38  https://www.huffpost.com/entry/another-starbuc...
# 39  https://www.huffpost.com/entry/world-markets-r...
#
#                                              headline       category  \
# 0   Reporter Gets Adorable Surprise From Her Boyfr...      U.S. NEWS
# 1   Puerto Ricans Desperate For Water After Hurric...     WORLD NEWS
# 2   4 Russian-Controlled Ukrainian Regions Schedul...     WORLD NEWS
# 3   Family Of American Held In Afghanistan Says He...      U.S. NEWS
# 4   WHO Raises Alarm On Disease In Flood-hit Areas...     WORLD NEWS
# 5   German Customs Officials Follow Trail Of Slime...     WEIRD NEWS
# 6   Bill To Help Afghans Who Escaped Taliban Faces...       POLITICS
# 7   Biden Honors 9/11 Victims, Vows Commitment To ...       POLITICS
# 8   Ukraine Claws Back Some Territory; Nuclear Pla...     WORLD NEWS
# 9   'Our Hearts Are Broken': Historic Front Pages ...     WORLD NEWS
# 10  Politician's DNA Connected To Las Vegas Journa...       POLITICS
# 11  Meta, Parent Company Of Instagram, Fined $400 ...      U.S. NEWS
# 12  Uvalde Fourth Graders Waited An Hour With Woun...       POLITICS
# 13  Obama's Foreign Policy: Continuity Rather Than...      WORLDPOST
# 14  Goodbye to Two of Our First Green Female Champ...          GREEN
# 15  Virgin Produced Launches Loyola Marymount Univ...  ENTERTAINMENT
# 16  Can Students Wear American Flag Clothing to Sc...      EDUCATION
# 17  South Korea Has Planned Kim Jong Un's Visit To...     WORLD NEWS
# 18  Trump's Michael Cohen Comments Are Already Cos...       POLITICS
# 19  Scott Pruitt Admits He Knew About Controversia...       POLITICS
# 20  Ronny Jackson Withdraws Name From VA Secretary...       POLITICS
# 21  Senate Gives Final Approval To Ukraine Aid, Hu...       POLITICS
# 22  Senate Gives Final Approval To Ukraine Aid, Hu...       POLITICS
# 23  NYC Sheds Vaccination Mandate, School Masks Pr...      U.S. NEWS
# 24  Blinken Vows U.S. Support To Moldova As War Ra...       POLITICS
# 25  Utah Gov. Spencer Cox Says He Plans To Veto Tr...       POLITICS
# 26  Kamala Harris To Travel To Poland And Romania ...       POLITICS
# 27  840 Children Wounded So Far In Russian Invasio...     WORLD NEWS
# 28  840 Children Wounded So Far In Russian Invasio...     WORLD NEWS
# 29  SUV Smashes Into California Preschool, Injurin...      U.S. NEWS
# 30  NJ Fines DraftKings $150,000 For Allowing Prox...      U.S. NEWS
# 31  Supreme Court Sides With Government In Gitmo S...      U.S. NEWS
# 32  Purdue Pharma, US States Agree To New Opioid S...      U.S. NEWS
# 33  Biden To Give First State Of The Union Address...       POLITICS
# 34  UN General Assembly, Security Council To Hold ...     WORLD NEWS
# 35  Russia Hits Ukraine Fuel Suplies, Airfields In...     WORLD NEWS
# 36  European Union Shuts Airspace To Russian Airli...     WORLD NEWS
# 37  UN To Scale Up Humanitarian Operations In Ukra...     WORLD NEWS
# 38          Another Starbucks Store Votes To Unionize       BUSINESS
# 39  Russian Military Action In Ukraine Causes Oil ...       BUSINESS
#
#                                     short_description  \
# 0   "Who's that behind you?" an anchor for New Yor...
# 1   More than half a million people remained witho...
# 2   The concerted and quickening Kremlin-backed ef...
# 3   Mark Frerichs, a Navy veteran and civilian con...
# 4   The World Health Organization is raising the a...
# 5   “Never in the history of the Duesseldorf custo...
# 6   Republican outrage over the shoddy U.S. withdr...
# 7   President Joe Biden has marked the 21st annive...
# 8   Ukrainian forces are claiming new success in t...
# 9   Both British and international newspapers hono...
# 10  Clark County Public Administrator Robert Telle...
# 11  The social media giant was fined for violation...
# 12  When Elsa Avila looks at the scar that runs do...
# 13  Alliances of convenience are the staple of for...
# 14  Today is the last day of women's history month...
# 15  Virgin Produced, the film, television, and ent...
# 16  School officials banned the wearing of the Ame...
# 17  Even the furniture and carpet for the North Ko...
# 18  The president may have shot himself in the foo...
# 19  The EPA administrator blamed the media, even a...
# 20  The Senate Veterans' Affairs Committee has bee...
# 21  The Senate has given final congressional appro...
# 22  The Senate has given final congressional appro...
# 23  "We did our job as New Yorkers and now we’re w...
# 24  The small Western-leaning former Soviet republ...
# 25  “I just want them to know that it’s gonna be o...
# 26  The vice president is meeting with NATO allies...
# 27  The head of Ukraine’s security council called ...
# 28  The head of Ukraine’s security council called ...
# 29  None of the injuries were life-threatening, po...
# 30  New Jersey gambling regulators have fined Draf...
# 31  The Supreme Court has ruled for the U.S. gover...
# 32  States agreed to sign on after the Sacklers ki...
# 33  President Joe Biden aims to navigate the count...
# 34  The Security Council gave a green light Sunday...
# 35  Russian forces blew up a gas pipeline in Khark...
# 36  The European Union is closing its airspace to ...
# 37  The UN will allocate $20 million to “help with...
# 38  The store in Arizona joins two in New York as ...
# 39  Asian and European stock markets plunged and o...
#
#                                               authors                 date  \
# 0                                       Elyse Wanshel  2022-09-22 00:00:00
# 1                                     DÁNICA COTO, AP  2022-09-22 00:00:00
# 2                                    Jon Gambrell, AP  2022-09-20 00:00:00
# 3                     Eric Tucker and Rahim Faiez, AP  2022-09-19 00:00:00
# 4                                      ZARAR KHAN, AP  2022-09-17 00:00:00
# 5                                                      2022-09-16 00:00:00
# 6                     Hamed Ahmadi and Arthur Delaney  2022-09-16 00:00:00
# 7                  COLLEEN LONG and AAMER MADHANI, AP  2022-09-11 00:00:00
# 8               HANNA ARHIROVA and YURAS KARMANAU, AP  2022-09-10 00:00:00
# 9                                      Kate Nicholson  2022-09-09 00:00:00
# 10                                    Sanjana Karanth  2022-09-08 00:00:00
# 11                                        Nick Visser  2022-09-06 00:00:00
# 12                                ACACIA CORONADO, AP  2022-09-05 00:00:00
# 13  Pierre Guerlain, ContributorProfessor, l'Unive...  2015-04-01 00:00:00
# 14  Heather Taylor-Miesle, ContributorExecutive Di...  2015-03-31 00:00:00
# 15  Mylen Fe Yamamoto, ContributorInventor of @Cro...  2015-03-31 00:00:00
# 16  Clay Calvert, ContributorProfessor and Brechne...  2015-03-31 00:00:00
# 17                                        Nick Visser  2018-04-26 00:00:00
# 18                                         Willa Frej  2018-04-26 00:00:00
# 19                               Alexander C. Kaufman  2018-04-26 00:00:00
# 20                                   Antonia Blumberg  2018-04-26 00:00:00
# 21                                      Alan Fram, AP  2022-03-11 00:00:00
# 22                                      Alan Fram, AP  2022-03-11 00:00:00
# 23                                                     2022-03-07 00:00:00
# 24                                    Matthew Lee, AP  2022-03-06 00:00:00
# 25                Sam Metz and Lindsay Whitehurst, AP  2022-03-05 00:00:00
# 26                                Sarah Ruiz-Grossman  2022-03-05 00:00:00
# 27                                                     2022-03-05 00:00:00
# 28                                                     2022-03-05 00:00:00
# 29                                                     2022-03-04 00:00:00
# 30                                    WAYNE PARRY, AP  2022-03-04 00:00:00
# 31                                 JESSICA GRESKO, AP  2022-03-03 00:00:00
# 32                Geoff Mulvihill and John Seewer, AP  2022-03-03 00:00:00
# 33                   ZEKE MILLER and COLLEEN LONG, AP  2022-03-01 00:00:00
# 34                               Edith M. Lederer, AP  2022-02-28 00:00:00
# 35  Yuras Karmanau, Jim Heintz, Vladimir Isachenko...  2022-02-27 00:00:00
# 36                EMILY SCHULTHEIS and LORNE COOK, AP  2022-02-27 00:00:00
# 37                               Edith M. Lederer, AP  2022-02-25 00:00:00
# 38                                      Dave Jamieson  2022-02-25 00:00:00
# 39                                   Joe McDonald, AP  2022-02-24 00:00:00
#
#           actor1     actor2 event_code goldstein_score  \
# 0            usa     ---med         20             3.0
# 1         ---ppl        usa        180            -9.0
# 2            ukr        rus         40             1.0
# 3            afg  ---milcvl        181            -9.0
# 4   igounohlhwho  pakhlhlab          8             5.0
# 5         ---med     ---med         10             0.0
# 6            usa     ---ref         51             3.4
# 7         usagov     usamil         30             4.0
# 8            ukr        rus         13             0.4
# 9         ---med        gbr         51             3.4
# 10        ---pty  usamedcop         60             6.0
# 11        ---bus     irlgov        172            -5.0
# 12        ---edu     ---edu        180            -9.0
# 13        usagov        irn         30             4.0
# 14        ---leg     ---leg         60             6.0
# 15           gbr  ---edubus         50             3.5
# 16        ---edu     ---edu        172            -5.0
# 17           kor     igouno         36               4
# 18        ---gov     ---gov        190             -10
# 19     usagovenv     ---med        112              -2
# 20     usagovleg     ---hlh         90              -2
# 21     usagovleg        ukr         51             3.4
# 22     usagovleg     ukrmil         51             3.4
# 23        ---gov     ---med         10             0.0
# 24           sun        rus         10             0.0
# 25        ---gov     ---cvl         10             0.0
# 26        ---gov  igowstnat         40             1.0
# 27        ---cvl        rus        180            -9.0
# 28           ukr        rus         20             3.0
# 29        usaedu  ---cvllab        182            -9.5
# 30        ---gov     usappl        172            -5.0
# 31        ---jud  usagovopp         42             1.9
# 32           usa     ---cvl         50             3.5
# 33        usagov        rus         40             1.0
# 34        igouno     ---leg         30             4.0
# 35           rus        ukr        190           -10.0
# 36     igoeureec     rusbus        172            -5.0
# 37        igouno     ---ppl        200           -10.0
# 38           usa        usa         40             1.0
# 39           rus        ukr        190           -10.0
#
#                                                 nouns  \
# 0   [new york, usa, united, states, of, america, j...
# 1   [people, ~ppl, ~, u.s., usa, united, states, o...
# 2   [ukrainian, ukr, ukraine, russia, rus, russian...
# 3   [navy, civilian, ~milcvl, ~, ~, afghanistan, a...
# 4   [world health organization, igounohlhwho, worl...
# 5                [spokesman, ~med, ~, media, ~med, ~]
# 6   [afghanistan, afg, afghanistan, u.s., usa, uni...
# 7   [president, joe biden, usagov, ~, joe, biden, ...
# 8   [ukrainian, ukr, ukraine, russian, rus, russia...
# 9    [newspapers, ~med, ~, u.k, gbr, united, kingdom]
# 10  [politician, ~pty, ~, las vegas, journalist, p...
# 11  [company, ~bus, ~, irish, regulators, irlgov, ...
# 12        [fourth graders, ~edu, ~, teacher, ~edu, ~]
# 13  [obama, usagov, barack, obama, iranian, irn, i...
# 14             [senators, ~leg, ~, congress, ~leg, ~]
# 15  [british, gbr, united, kingdom, entrepreneur, ...
# 16  [school, ~edu, ~, school, ~edu, ~, school, ~ed...
# 17   [south korea, kor, south, korea, un, igouno, un]
# 18                               [president, ~gov, ~]
# 19  [epa, usagovenv, environmental, protection, ag...
# 20  [senate, usagovleg, united, states, congress, ...
# 21  [senate, usagovleg, united, states, congress, ...
# 22  [senate, usagovleg, united, states, congress, ...
# 23                      [mayor, ~gov, ~, tv, ~med, ~]
# 24  [soviet, sun, soviet, union, ukraine, ukr, ukr...
# 25             [governor, ~gov, ~, athletes, ~cvl, ~]
# 26  [president, ~gov, ~, nato, igowstnat, nato, uk...
# 27  [children, ~cvl, ~, russian, rus, russian, fed...
# 28  [ukraine, security council, ukr, igouno, ukrai...
# 29  [california, preschool, usaedu, united, states...
# 30  [regulators, ~gov, ~, florida, man, usappl, un...
# 31  [supreme court, ~jud, ~, u.s., government, usa...
# 32  [us, usa, united, states, of, america, settlem...
# 33  [president, joe biden, usagov, ~, joe, biden, ...
# 34  [the security council, igouno, the, security, ...
# 35  [russian, rus, russian, federation, kharkiv, u...
# 36  [the european union, igoeureec, the, european,...
# 37  [the un, igouno, the, un, people, ~ppl, ~, peo...
# 38  [arizona, usa, united, states, of, america, st...
# 39  [russia, rus, russian, federation, ukraine, uk...
#
#                                             actortext  \
# 0                              [new york, journalist]
# 1                                      [people, u.s.]
# 2                                 [ukrainian, russia]
# 3                    [afghanistan, navy ... civilian]
# 4                    [world health organization, ---]
# 5                              [spokesman, spokesman]
# 6                                    [u.s., refugees]
# 7                     [president joe biden, pentagon]
# 8                                [ukrainian, russian]
# 9                                   [newspapers, u.k]
# 10      [politician, las vegas journalist ... police]
# 11                        [company, irish regulators]
# 12                   [fourth graders, fourth graders]
# 13                                   [obama, iranian]
# 14                               [senators, senators]
# 15             [british, university ... entrepreneur]
# 16                                   [school, school]
# 17                                  [south korea, un]
# 18                             [president, president]
# 19                                       [epa, media]
# 20                                [senate, physician]
# 21                                  [senate, ukraine]
# 22                                 [senate, military]
# 23                                        [mayor, tv]
# 24                                   [soviet, russia]
# 25                               [governor, athletes]
# 26                                  [president, nato]
# 27                                [children, russian]
# 28        [ukraine, russia, security council, russia]
# 29      [california preschool, children ... employee]
# 30                          [regulators, florida man]
# 31                               [supreme court, ---]
# 32                                   [us, settlement]
# 33                      [president joe biden, russia]
# 34           [the security council, general assembly]
# 35                                 [russian, kharkiv]
# 36  [the european union, russian airlines, the eur...
# 37                                   [the un, people]
# 38                                 [arizona, arizona]
# 39                                  [russia, ukraine]
#
#                                             actorroot  \
# 0                     [united states of america, ---]
# 1                     [---, united states of america]
# 2                       [ukraine, russian federation]
# 3                                  [afghanistan, ---]
# 4                    [world health organization, ---]
# 5                                          [---, ---]
# 6                     [united states of america, ---]
# 7                 [joe biden, united states military]
# 8                       [ukraine, russian federation]
# 9                               [---, united kingdom]
# 10                    [---, united states of america]
# 11                                     [---, ireland]
# 12                                         [---, ---]
# 13                               [barack obama, iran]
# 14                                         [---, ---]
# 15                              [united kingdom, ---]
# 16                                         [---, ---]
# 17                                  [south korea, un]
# 18                                         [---, ---]
# 19             [environmental protection agency, ---]
# 20                      [united states congress, ---]
# 21                  [united states congress, ukraine]
# 22                         [united states congress, ]
# 23                                         [---, ---]
# 24                 [soviet union, russian federation]
# 25                                         [---, ---]
# 26                                        [---, nato]
# 27                          [---, russian federation]
# 28  [ukraine, russian federation, un security coun...
# 29                    [united states of america, ---]
# 30                    [---, united states of america]
# 31                                         [---, ---]
# 32                    [united states of america, ---]
# 33                    [joe biden, russian federation]
# 34                        [the security council, ---]
# 35                      [russian federation, ukraine]
# 36  [the european union, russian federation, the e...
# 37                                      [the un, ---]
# 38  [united states of america, united states of am...
# 39                      [russian federation, ukraine]
#
#                                             eventtext  \
# 0                                             [asked]
# 1                               [remained ... lashed]
# 2                                 [schedule ... join]
# 3       [<~milcvl> ... kidnapped in afg ... in <--->]
# 4                                 [raising ... alarm]
# 5                                              [told]
# 6                                   [has ... spurred]
# 7        [has marked ... anniversary ... taking part]
# 8                          [are claiming ... success]
# 9                                             [honor]
# 10                                        [connected]
# 11                                            [fined]
# 12                                          [wounded]
# 13                                            [wants]
# 14                                      [have served]
# 15                                     [collaborated]
# 16                                           [banned]
# 17                            [has planned ... visit]
# 18                                     [may ... shot]
# 19                                           [blamed]
# 20                            [has ... investigating]
# 21                               [gives ... approval]
# 22                           [has given ... approval]
# 23                                             [said]
# 24                                  [is ... watching]
# 25                                             [said]
# 26                                       [is meeting]
# 27                                          [wounded]
# 28                             [called on, called on]
# 29                                         [injuring]
# 30                                       [have fined]
# 31                                    [has ruled for]
# 32                                            [agree]
# 33                                [aims ... confront]
# 34                           [gave <{green> <light}>]
# 35                               [<['blew',> <'up']>]
# 36  [is closing ... airspace, is ... supply <&weap...
# 37                           [will allocate ... help]
# 38                                            [joins]
# 39                                         [attacked]
#
#                             issues  \
# 0                             None
# 1                             None
# 2                             None
# 3                             None
# 4            [natural_disaster, 1]
# 5                [id_smuggling, 1]
# 6                    [refugees, 1]
# 7                             None
# 8                             None
# 9                             None
# 10          [security_services, 1]
# 11                            None
# 12                   [teachers, 1]
# 13                            None
# 14                            None
# 15    [postsecondary_education, 1]
# 16                    [schools, 2]
# 17                             NaN
# 18                             NaN
# 19                             NaN
# 20                             NaN
# 21                            None
# 22                            None
# 23                            None
# 24                   [refugees, 1]
# 25                   [students, 1]
# 26                            None
# 27                            None
# 28                            None
# 29  [early_childhood_education, 1]
# 30                            None
# 31                            None
# 32                            None
# 33                [id_pandemic, 1]
# 34                            None
# 35                            None
# 36                            None
# 37                            None
# 38                            None
# 39                            None
#
#                                            events
# 0                              [usa, ---med, 020]
# 1                              [---ppl, usa, 180]
# 2                                 [ukr, rus, 040]
# 3                           [afg, ---milcvl, 181]
# 4                   [igounohlhwho, pakhlhlab, 08]
# 5                           [---med, ---med, 010]
# 6                              [usa, ---ref, 051]
# 7                           [usagov, usamil, 030]
# 8                                 [ukr, rus, 013]
# 9                              [---med, gbr, 051]
# 10                       [---pty, usamedcop, 060]
# 11                          [---bus, irlgov, 172]
# 12                          [---edu, ---edu, 180]
# 13                             [usagov, irn, 030]
# 14                          [---leg, ---leg, 060]
# 15                          [gbr, ---edubus, 050]
# 16                          [---edu, ---edu, 172]
# 17                             [kor, igouno, 036]
# 18                          [---gov, ---gov, 190]
# 19                       [usagovenv, ---med, 112]
# 20                       [usagovleg, ---hlh, 090]
# 21                          [usagovleg, ukr, 051]
# 22                       [usagovleg, ukrmil, 051]
# 23                          [---gov, ---med, 010]
# 24                                [sun, rus, 010]
# 25                          [---gov, ---cvl, 010]
# 26                       [---gov, igowstnat, 040]
# 27                             [---cvl, rus, 180]
# 28              [ukr, rus, 020, igouno, rus, 020]
# 29                       [usaedu, ---cvllab, 182]
# 30                          [---gov, usappl, 172]
# 31                       [---jud, usagovopp, 042]
# 32                             [usa, ---cvl, 050]
# 33                             [usagov, rus, 040]
# 34                          [igouno, ---leg, 030]
# 35                                [rus, ukr, 190]
# 36  [igoeureec, rusbus, 172, igoeureec, ukr, 072]
# 37                          [igouno, ---ppl, 200]
# 38                                [usa, usa, 040]
# 39                                [rus, ukr, 190]

# %%
#Save final processed file to disk
country_relations.to_json(f"country_relations_final.json", indent = 2)

# %%
#Reload final file
country_relations_final = pd.read_json("country_relations_final.json")
country_relations_final.head()
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/reporter-gets-a...
# 1  https://www.huffpost.com/entry/puerto-rico-wat...
# 2  https://www.huffpost.com/entry/russian-control...
# 3  https://www.huffpost.com/entry/mark-frerichs-r...
# 4  https://www.huffpost.com/entry/bc-as-pakistan-...
#
#                                             headline    category  \
# 0  Reporter Gets Adorable Surprise From Her Boyfr...   U.S. NEWS
# 1  Puerto Ricans Desperate For Water After Hurric...  WORLD NEWS
# 2  4 Russian-Controlled Ukrainian Regions Schedul...  WORLD NEWS
# 3  Family Of American Held In Afghanistan Says He...   U.S. NEWS
# 4  WHO Raises Alarm On Disease In Flood-hit Areas...  WORLD NEWS
#
#                                    short_description  \
# 0  "Who's that behind you?" an anchor for New Yor...
# 1  More than half a million people remained witho...
# 2  The concerted and quickening Kremlin-backed ef...
# 3  Mark Frerichs, a Navy veteran and civilian con...
# 4  The World Health Organization is raising the a...
#
#                            authors       date        actor1     actor2  \
# 0                    Elyse Wanshel 2022-09-22           usa     ---med
# 1                  DÁNICA COTO, AP 2022-09-22        ---ppl        usa
# 2                 Jon Gambrell, AP 2022-09-20           ukr        rus
# 3  Eric Tucker and Rahim Faiez, AP 2022-09-19           afg  ---milcvl
# 4                   ZARAR KHAN, AP 2022-09-17  igounohlhwho  pakhlhlab
#
#    event_code  goldstein_score  \
# 0          20              3.0
# 1         180             -9.0
# 2          40              1.0
# 3         181             -9.0
# 4           8              5.0
#
#                                                nouns  \
# 0  [new york, usa, united, states, of, america, j...
# 1  [people, ~ppl, ~, u.s., usa, united, states, o...
# 2  [ukrainian, ukr, ukraine, russia, rus, russian...
# 3  [navy, civilian, ~milcvl, ~, ~, afghanistan, a...
# 4  [world health organization, igounohlhwho, worl...
#
#                           actortext                         actorroot  \
# 0            [new york, journalist]   [united states of america, ---]
# 1                    [people, u.s.]   [---, united states of america]
# 2               [ukrainian, russia]     [ukraine, russian federation]
# 3  [afghanistan, navy ... civilian]                [afghanistan, ---]
# 4  [world health organization, ---]  [world health organization, ---]
#
#                                        eventtext                 issues  \
# 0                                        [asked]                   None
# 1                          [remained ... lashed]                   None
# 2                            [schedule ... join]                   None
# 3  [<~milcvl> ... kidnapped in afg ... in <--->]                   None
# 4                            [raising ... alarm]  [natural_disaster, 1]
#
#                           events
# 0             [usa, ---med, 020]
# 1             [---ppl, usa, 180]
# 2                [ukr, rus, 040]
# 3          [afg, ---milcvl, 181]
# 4  [igounohlhwho, pakhlhlab, 08]
