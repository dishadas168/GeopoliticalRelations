# %%
import glob, os
import json
import pandas as pd

json_dir = 'json_dir'

json_pattern = os.path.join(json_dir, '*.json')
file_list = glob.glob(json_pattern)

field_names = ['link', 'headline', 'category', 'short_description', 'authors', 'date',
              'actor1', 'actor2', 'event_code', 'goldstein_score', 'nouns', 'actortext', 'actorroot',
              'eventtext', 'issues', 'events']

country_relations = pd.DataFrame(columns = field_names)

for file in file_list:
    temp_df = pd.read_json(file)
    country_relations = pd.concat([country_relations, temp_df], axis =0)

country_relations.reset_index(inplace=True)
country_relations.drop(['index'], axis = 1, inplace =True)
print(country_relations.shape)
country_relations.tail(100)
# Out:
# (2487, 16)
#                                                    link  \
# 2387  https://www.huffingtonpost.com/entry/results-f...
# 2388  https://www.huffingtonpost.com/entry/north-kor...
# 2389  https://www.huffingtonpost.com/entry/women-acc...
# 2390  https://www.huffingtonpost.com/entry/harvey-we...
# 2391  https://www.huffingtonpost.com/entry/white-hou...
# ...                                                 ...
# 2482  https://www.huffingtonpost.com/entry/israel-ga...
# 2483  https://www.huffingtonpost.com/entry/israel-ki...
# 2484  https://www.huffingtonpost.com/entry/israel-ki...
# 2485  https://www.huffingtonpost.com/entry/fbi-congr...
# 2486  https://www.huffingtonpost.com/entry/michigan-...
#
#                                                headline       category  \
# 2387  Ireland Votes To Repeal Abortion Amendment In ...       POLITICS
# 2388  North Korea Threatens Again To Call Off Trump ...     WORLD NEWS
# 2389  Morgan Freeman Accused Of Inappropriate Behavi...          WOMEN
# 2390  Harvey Weinstein Expected To Turn Himself In T...  ENTERTAINMENT
# 2391  White House Officials Reportedly Considered Ju...       POLITICS
# ...                                                 ...            ...
# 2482  Palestinian Teen Dies After Being Shot By Isra...     WORLD NEWS
# 2483  Israeli Forces Kill 3 Gaza Border Protesters, ...     WORLD NEWS
# 2484  Israeli Forces Kill 3 Gaza Border Protesters, ...     WORLD NEWS
# 2485  White House Knew About Rob Porter Allegations ...       POLITICS
# 2486  Michigan GOP Politician Is Spreading Conspirac...       POLITICS
#
#                                       short_description  \
# 2387  Irish women will no longer have to travel to t...
# 2388  A top Pyongyang official lambasted "political ...
# 2389  Eight people told CNN that they were victims o...
# 2390  Authorities in New York have been investigatin...
# 2391  An internal memo obtained by The Washington Po...
# ...                                                 ...
# 2482  Israeli forces have killed 42 Palestinians sin...
# 2483  Israeli troops have killed 41 Palestinians and...
# 2484  Israeli troops have killed 41 Palestinians and...
# 2485  The letter to Congress contradicts the White H...
# 2486  Abdul El-Sayed’s team says Republican leaders ...
#
#                          authors                 date  actor1  actor2  \
# 2387               Laura Bassett  2018-05-26 00:00:00  irlcvl     gbr
# 2388         Dominique Mosbergen  2018-05-24 00:00:00     prk     usa
# 2389           Sebastian Murdock  2018-05-24 00:00:00  ---ppl     med
# 2390                Sara Boboltz  2018-05-24 00:00:00  usagov  ---bus
# 2391         Dominique Mosbergen  2018-05-24 00:00:00     med  ---gov
# ...                          ...                  ...     ...     ...
# 2482  Nidal al-Mughrabi, Reuters  2018-04-28 00:00:00     isr     pse
# 2483  Nidal al-Mughrabi, Reuters  2018-04-27 00:00:00     isr  ---opp
# 2484  Nidal al-Mughrabi, Reuters  2018-04-27 00:00:00  isrmil     pse
# 2485                 Doha Madani  2018-04-27 00:00:00  ---leg  usagov
# 2486             Carol Kuruvilla  2018-04-27 00:00:00  usapty  ---mus
#
#      event_code goldstein_score  \
# 2387         40             1.0
# 2388        130            -4.4
# 2389         10             0.0
# 2390         90            -2.0
# 2391         30             4.0
# ...         ...             ...
# 2482        190           -10.0
# 2483        190           -10.0
# 2484        190           -10.0
# 2485        110            -2.0
# 2486         10             0.0
#
#                                                   nouns  \
# 2387  [irish, women, irlcvl, ireland, ~, united king...
# 2388  [pyongyang, prk, north, korea, u.s., usa, unit...
# 2389  [people, ~ppl, ~, cnn, med, cnn, actor, ~eli, ...
# 2390  [new york, usa, united, states, of, america, a...
# 2391  [washington post, med, washington, post, admin...
# ...                                                 ...
# 2482  [israeli, isr, israel, palestinians, pse, pale...
# 2483        [israeli, isr, israel, protesters, ~opp, ~]
# 2484  [israeli, troops, isrmil, israel, ~, palestini...
# 2485  [congress, ~leg, ~, congress, ~leg, ~, the whi...
# 2486  [michigan, politician, usapty, united, states,...
#
#                               actortext  \
# 2387      [irish women, united kingdom]
# 2388                  [pyongyang, u.s.]
# 2389                      [people, cnn]
# 2390            [authorities, producer]
# 2391  [washington post, administration]
# ...                                 ...
# 2482            [israeli, palestinians]
# 2483              [israeli, protesters]
# 2484     [israeli troops, palestinians]
# 2485    [congress, the ... white house]
# 2486  [michigan ... politician, muslim]
#
#                                     actorroot                 eventtext  \
# 2387                [ireland, united kingdom]         [will ... travel]
# 2388  [north korea, united states of america]     [<and> ... cautioned]
# 2389                               [---, cnn]                    [told]
# 2390                                  [, ---]  [have ... investigating]
# 2391                   [washington post, ---]                  [offers]
# ...                                       ...                       ...
# 2482                      [israel, palestine]             [have killed]
# 2483                            [israel, ---]                    [kill]
# 2484                      [israel, palestine]             [have killed]
# 2485                       [---, white house]             [contradicts]
# 2486          [united states of america, ---]            [is spreading]
#
#                     issues                 events
# 2387                  None     [irlcvl, gbr, 040]
# 2388                  None        [prk, usa, 130]
# 2389                  None     [---ppl, med, 010]
# 2390  [gender_violence, 1]  [usagov, ---bus, 090]
# 2391   [climate_change, 1]     [med, ---gov, 030]
# ...                    ...                    ...
# 2482                  None        [isr, pse, 190]
# 2483                  None     [isr, ---opp, 190]
# 2484                  None     [isrmil, pse, 190]
# 2485                  None  [---leg, usagov, 110]
# 2486                  None  [usapty, ---mus, 010]
#
# [100 rows x 16 columns]

# %%
country_relations['date'].sort_values()
# Out:
# 2157   2016-08-20
# 2156   2016-08-20
# 2155   2016-08-20
# 2154   2016-08-20
# 2153   2016-08-20
#           ...
# 4      2022-09-17
# 3      2022-09-19
# 2      2022-09-20
# 1      2022-09-22
# 0      2022-09-22
# Name: date, Length: 2487, dtype: datetime64[ns]
